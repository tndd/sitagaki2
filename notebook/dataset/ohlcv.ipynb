# %%
from domain.dataset.common import read_df

df = read_df("aapl")
df
# Out:
#                Close     Volume      Open      High       Low
# Date
# 2015-02-26   32.6037  364687320   32.1962   32.7175   31.6525
# 2015-02-27   32.1150  247725400   32.5000   32.6425   32.0600
# 2015-03-02   32.2725  192170720   32.3125   32.5700   32.0750
# 2015-03-03   32.3400  150999600   32.2400   32.3800   32.0225
# 2015-03-04   32.1350  126353920   32.2750   32.3900   32.0800
# ...              ...        ...       ...       ...       ...
# 2025-02-19  244.8700   32204220  244.6600  246.0100  243.1604
# 2025-02-20  245.8300   32316910  244.9400  246.7800  244.2900
# 2025-02-21  245.5500   53197430  245.9500  248.6900  245.2200
# 2025-02-24  247.1000   51326400  244.9250  248.8600  244.4200
# 2025-02-25  247.0400   48013270  248.0000  250.0000  244.9100
#
# [2515 rows x 5 columns]

# %%
from icecream import ic

from domain.dataset.ohlcv import Ohlcv

ohlcv = Ohlcv(df)
ic(ohlcv.columns)
# Out:
# ic| ohlcv.columns: ['Open', 'High', 'Low', 'Close', 'Volume']
# ['Open', 'High', 'Low', 'Close', 'Volume']
