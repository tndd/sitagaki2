# %%
from fixture.domain.feature.lag import factory_lag_closes10

lag = factory_lag_closes10()
lag.df
# Out:
#               Open    High     Low   Close   Volume        l0        l1  \
# Date
# 2020-01-16  105.43  108.45  104.89  105.55   664848 -0.014205 -0.002426
# 2020-01-17  106.53  109.04  104.72  106.01   100000  0.004349 -0.014205
# 2020-01-20  102.89  105.55  102.30  103.36  1168808 -0.025315  0.004349
# 2020-01-21  100.63  101.85   98.37  101.54   242028 -0.017765 -0.025315
# 2020-01-22   99.53  100.62   98.58  100.23   924672 -0.012985 -0.017765
# ...            ...     ...     ...     ...      ...       ...       ...
# 2023-10-25  210.69  212.93  206.38  210.13   145129 -0.019324 -0.002936
# 2023-10-26  215.92  219.85  213.51  219.11  1295392  0.041848 -0.019324
# 2023-10-27  220.82  223.35  218.16  219.96  1100396  0.003872  0.041848
# 2023-10-30  218.38  220.90  216.16  218.47   617748 -0.006797  0.003872
# 2023-10-31  220.34  227.02  220.04  222.07  1254619  0.016344 -0.006797
#
#                   l2        l3        l4        l5        l6        l7  \
# Date
# ...
