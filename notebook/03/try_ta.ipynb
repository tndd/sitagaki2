# %%
import polars_talib as plta
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import polars_talib as plta
#
# File ~/repository/sitagaki2/.venv/lib/python3.13/site-packages/polars_talib/__init__.py:4
#       2 import polars as pl
#       3 from .utils import register_plugin, parse_version
# ----> 4 from ._polars_talib import initialize, shutdown, version
#       5 from pathlib import Path
#       8 __talib_version__ = version()
#
# ImportError: dlopen(/Users/tau/repository/sitagaki2/.venv/lib/python3.13/site-packages/polars_talib/_polars_talib.abi3.so, 0x0002): symbol not found in flat namespace '_TA_ACOS'
